# %%
from src.learner import Learner
from argparse import Namespace

# %% [markdown]
# ## Args

# %%
args = Namespace(dataset_csv="data/nmt/simplest_eng_fra.csv",
                 vectorizer_file="vectorizer.json",
                 model_state_file="model.pth",
                 save_dir="model_storage/ch8/nmt_luong_sampling",
                 reload_from_files=False,
                 expand_filepaths_to_save_dir=True,
                 cuda=True,
                 seed=1337,
                 learning_rate=5e-4,
                 batch_size=32,
                 num_epochs=3,
                 early_stopping_criteria=5,              
                 source_embedding_size=24, 
                 target_embedding_size=24,
                 encoding_size=32,
                 catch_keyboard_interrupt=True,
                 sampling=True)

# %% [markdown]
# ## Learner

# %%
learner=Learner.learner_from_args(args)
# Out:
# Expanded filepaths:
# 	model_storage/ch8/nmt_luong_sampling\vectorizer.json
# 	model_storage/ch8/nmt_luong_sampling\model.pth
# Using CUDA: False
# Loading dataset and creating vectorizer

# %% [markdown]
# ## train

# %%
learner.train()
# Out:
# HBox(children=(IntProgress(value=0, description='training routine', max=3, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='split=train', max=285, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='split=val', max=61, style=ProgressStyle(description_width='in…

# %% [markdown]
# ## Bleu

# %%
learner.calc_bleu()
# Out:
# bleu-4 mean for test data: 0.23020164915614075
# bleu-4 median for test data: 0.20466639148435495

# %% [markdown]
# ## See predictions

# %%
learner.plot_top_val_sentences(max_n=5)
# Out:
# sentence over threshold: 20

# %%
learner.get_val_1batch_sentence(1)
# Out:
# {'source': "i 'm sorry , but i already have a girlfriend .",
#  'truth': "je suis désolée , mais j'ai déjà une petite amie .",
#  'sampled': 'je suis pas de . . . . . . .'}

# %% [markdown]
# ## Load saved model

# %%
args_saved = Namespace(dataset_csv="data/nmt/simplest_eng_fra.csv",
                 vectorizer_file="vectorizer.json",
                 model_state_file="model.pth",
                 save_dir="model_storage/ch8/nmt_luong_sampling",
                 reload_from_files=True,
                 expand_filepaths_to_save_dir=True,
                 cuda=True,
                 seed=1337,
                 learning_rate=5e-4,
                 batch_size=32,
                 num_epochs=3,
                 early_stopping_criteria=5,              
                 source_embedding_size=24, 
                 target_embedding_size=24,
                 encoding_size=32,
                 catch_keyboard_interrupt=True,
                 sampling=True)

# %%
learner_loaded=Learner.learner_from_args(args_saved)
# Out:
# Expanded filepaths:
# 	model_storage/ch8/nmt_luong_sampling\vectorizer.json
# 	model_storage/ch8/nmt_luong_sampling\model.pth
# Using CUDA: False
# Loading dataset and loading vectorizer

# %%
learner_loaded.calc_bleu()
# Out:
# bleu-4 mean for test data: 0.23041477434763816
# bleu-4 median for test data: 0.2047622407222799
